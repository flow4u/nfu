# %% [markdown]
# # Extract the Codebook HTML into a dataframe
#
# This notebook is capable of converting a local downloaded version of the ISARIC Codebook (save as single web page) into a dataframe containg the:
# ID, Variable / Field Name, Field Label, Field Attributes, Dictionary (option value and label)
#
# Usage:
# - Save the ISARIC Codebook as Single web page locally
# - Put in same folder as this Notebook
# - Run

# %%
import re
import pandas as pd
from tabulate import tabulate
from bs4 import BeautifulSoup                       # Beautiful Soup Version 4
RA_Works = 0                                        # Initiate the Count

# location of the download webpage containing the ISARIC Codebook
url = './ISARIC COVID-19 CORE & Follow-up _ REDCap.html'

# Read and create a soup from the url
f = open(url, 'r')
s = f.read()
soup = BeautifulSoup(s,"html")


# define the column names of the codebook
columns = ['id', 'variable', 'label', 'type', 'dict']

# create the dataframe for the codebook
df_codebook = pd.DataFrame(index=[], columns=columns)

# soupify the lot
tables = soup.find_all('table')

# it appears the Codebook is the second table
table_body = tables[1].find('tbody')

# find all the rows in the table of the Codebook
rows = table_body.find_all('tr')

# counter to make sure the correct rows are identified based on the '#' in the Codebook
x=1
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    try:
        if int(cols[0]) == x:
            new_id = cols[0]
            new_variable = cols[1].split('\n',1)[0]
            new_label = cols[2]
            new_type = re.split('\d+', cols[3])[0]
            new_dict = {}
            try:
                lst = cols[4:]
                new_dict = {lst[i]: lst[i+1] for i in range(0, len(lst),2)}
            except:
                pass
            new_item = pd.Series([new_id, new_variable, new_label, new_type, new_dict], index=columns)
            df_codebook = df_codebook.append(new_item, ignore_index=True)
            x=x+1
    except:
        pass

# make a copy of df_codebook to display the codebook in readable format
# for this 'label', 'type', 'dict' must be maximized to contain n characters
n = 25
df_codebook_temp = df_codebook.copy()
df_codebook_temp['label'] = df_codebook_temp['label'].str[:n]
df_codebook_temp['type'] = df_codebook_temp['type'].str[:n]
df_codebook_temp['dict'] = df_codebook_temp['dict'].astype(str)
df_codebook_temp['dict'] = df_codebook_temp['dict'].str[:n]
    
print(tabulate(df_codebook_temp, columns, tablefmt='rst'))#, tablefmt="github"))
# Out:
# ====  ====  ========================================================  ==========================  =========================  =========================
#   ..    id  variable                                                  label                       type                       dict
# ====  ====  ========================================================  ==========================  =========================  =========================
#    0     1  subjid                                                    Participant Identificatio  text                       {}
#    1     2  participant_identification_number_pin_complete            Section Header: Form Stat  dropdown                   {'0': 'Incomplete', '1':
#    2     3  tos_v2                                                    Please click on the PDF d  descriptive                {}
#    3     4  tos_facat_v2                                              There are two mechanisms   radio                      {'1': 'Via electronic sig
#    4     5  nov_fayn_v2                                               These Terms of Data Submi  radio, Required            {'1': 'Accept', '2': 'Not
#    5     6  tosretropaper_faorres_v2                                  Upload signed pdf copy of  file                       {}
#    6     7  tos_licensing_v2                                          Please choose and confirm  radio, Required            {'1': 'I have read and ag
#    7     8  signature_v2                                              Signature                  file (signature), Require  {}
#    8     9  name_v2                                                   Name                       text, Required             {}
#    9    10  email_v2                                                  Email Address(this will b  text (email)               {}
#   10    11  role_v2                                                   Role/Organisation          text, Required             {}
#   11    12  date_v2                                                   Date                       text (date_dmy), Required  {}
#   12    13  data_platform_terms_of_submission_july_20202_complete     Section Header: Form Stat  dropdown                   {'0': 'Incomplete', '1':
#   13    14  tos                                                       Please click on the PDF d  descriptive                {}
#   14    15  tos_facat                                                 There are two mechanisms   radio                      {'1': 'Via electronic sig
#   15    16  nov_fayn                                                  These Terms of Data Submi  radio, Required            {'1': 'Accept', '2': 'Not
#   16    17  tosretropaper_faorres                                     Upload signed pdf copy of  file                       {}
#   17    18  tos_licensing                                             Please choose and confirm  radio, Required            {'1': 'I have read and ag
#   18    19  signature                                                 Signature                  file (signature), Require  {}
#   19    20  name                                                      Name                       text, Required             {}
#   20    21  email                                                     Email Address(this will b  text (email)               {}
#   21    22  role                                                      Role/Organisation          text, Required             {}
#   22    23  date                                                      Date                       text (date_dmy), Required  {}
#   23    24  data_platform_terms_of_submission_complete                Section Header: Form Stat  dropdown                   {'0': 'Incomplete', '1':
#   24    25  dsstdat                                                   Enrolment date / first CO  text (date_dmy), Required  {}
#   25    26  sitename                                                  Clinical centre name:      text, Required             {}
#   26    27  country                                                   Country                    dropdown, Required         {'1': 'Afghanistan', '2':
#   27    28  othcountry                                                Other country              text                       {}
#   28    29  corona_ieorres                                            Section Header: CLINICAL   yesno, Required            {'1': 'Yes', '0': 'No'}
#   29    30  symptoms_epi_travel                                       Section Header: EPIDEMIOL  radio (Matrix), Required   {'1': 'YES', '2': 'NO', '
#   30    31  symptoms_epi_physical                                     3.Close contact* with a c  radio (Matrix), Required   {'1': 'YES', '2': 'NO', '
#   31    32  symptoms_epi_healthfac                                    4.Presence in a healthcar  radio (Matrix), Required   {'1': 'YES', '2': 'NO', '
#   32    33  symptoms_epi_lab                                          5. Presence in a laborato  radio (Matrix), Required   {'1': 'YES', '2': 'NO', '
#   33    34  symptoms_epi_animal                                       6.Direct contact with ani  radio (Matrix), Required   {'1': 'YES', '2': 'NO', '
#   34    35  contact                                                   * Close contact' is defin  descriptiveField Annotati  {}
#   35    36  inclusion_criteria_complete                               Section Header: Form Stat  dropdown                   {'0': 'Incomplete', '1':
#   36    37  ethnic                                                    Section Header: DEMOGRAPH  checkbox                   {'1': 'ethnic___1', 'Arab
#   37    38  other_ethnic                                              Ethnic group - If Other:   text                       {}
#   38    39  healthwork_erterm                                         Employed as a healthcare   radio, Required            {'1': 'YES', '2': 'NO', '
#   39    40  labwork_erterm                                            Employed in a microbiolog  radio, Required            {'1': 'YES', '2': 'NO', '
#   40    41  sex                                                       Sex at Birth:              radio, Required, Identifi  {'1': 'Male', '2': 'Femal
#   41    42  age_estimateyears                                         AgeIf patient is a child   text (number, Min:         {}
#   42    43  age_estimateyearsu                                        Age Unit                   dropdown, Required         {'1': 'Months', '2': 'Yea
#   43    44  pregyn_rptestcd                                           Pregnant?                  radio, Required            {'1': 'YES', '0': 'NO', '
#   44    45  egestage_rptestcd                                         If YES: Gestational weeks  text (number, Min:         {}
#   45    46  postpart_rptestcd                                         Post Partum? (within 6 we  radio, Required            {'1': 'YES', '0': 'NO', '
#   46    47  pregout_rptestcd                                          Pregnancy Outcome          radio, Required            {'1': 'Live birth', '2':
#   47    48  dlvrdtc_rptestcd                                          Delivery date:             text (date_dmy), Required  {}
#   48    49  aplb_lbperf                                               Baby tested for COVID-19/  radio, Required            {'1': 'YES', '2': 'NO', '
#   49    50  aplb_lborres                                              Baby tested for COVID-19/  radio, Required            {'1': 'Positive', '2': 'N
#   50    51  aplb_lbmethod                                             1.6.4 Method               radio, Required            {'1': 'PCR', '2': 'Other'
#   51    52  aplb_lbmethodoth                                          If OTHER method; Specify   text, RequiredField Annot  {}
#   52    53  apdm_age                                                  INFANT - Less than 1 year  yesno, Required            {'1': 'Yes', '0': 'No'}
#   53    54  apvs_weight                                               Birth weight               text (number, Min:         {}
#   54    55  apvs_weightu                                              Birth weight unit          dropdown, Required         {'1': 'kg', '2': 'lbs'}
#   55    56  apsc_gestout                                              Gestational outcome        radio, Required            {'1': 'Term birth ( >= 37
#   56    57  apsc_brfed                                                Breastfed?                 radio, Required            {'1': 'YES - currently br
#   57    58  apsc_brfedind                                             1.7.3 Breastfed            radio, Required            {'1': 'Yes', '2': 'No', '
#   58    59  apsc_brfedindy                                            If  YES                    radio, Required            {'1': 'Currently breastfe
#   59    60  apsc_brdisdat                                             Discontinued breastfeedin  text (number, Min:         {}
#   60    61  apsc_dvageind                                             1.7.4 Appropriate develop  dropdown, Required         {'1': 'Yes', '2': 'No', '
#   61    62  apsc_vcageind                                             Vaccinations appropriate   radio, Required            {'1': 'Yes', '2': 'No', '
#   62    63  demographics_complete                                     Section Header: Form Stat  dropdown                   {'0': 'Incomplete', '1':
#   63    64  cestdat                                                   Section Header: ONSET & A  text (date_dmy), Required  {}
#   64    65  hostdat                                                   Most recent presentation/  text (date_dmy), Required  {}
#   65    66  hosttim                                                   2.3 Admission time at thi  text (time)Field Annotati  {}
#   66    67  hooccur                                                   2.4 Transfer from other f  radio                      {'1': 'Yes-facility is a
#   67    68  siteid_transfer                                           2.5.1 If YES: Name of tra  textField Annotation: @HI  {}
#   68    69  hostdat_transfer                                          2.5.2 If YES: Admission d  text (date_dmy)Field Anno  {}
#   69    70  subjidcat_transfer                                        2.5.3 If YES - Study Site  radio                      {'1': 'Same as above', '2
#   70    71  subjid_transfer                                           If DIFFERENT; Participant  textField Annotation: @HI  {}
#   71    72  travel_erterm                                             2.6 Travel in the 14 days  radio                      {'1': 'Yes', '2': 'No', '
#   72    73  supper_trcntry                                            2.6.1 If YES, state locat  dropdown (autocomplete)    {'4': 'Afghanistan', '5':
#   73    74  supper_trcity                                             2.6.2 If YES, state locat  textField Annotation: @HI  {}
#   74    75  erendat                                                   2.6.3 If YES, return date  text (date_dmy)Field Anno  {}
#   75    76  travel_erterm_2                                           2.6.4 Travelled to anothe  radio                      {'1': 'Yes', '2': 'No', '
#   76    77  supper_trcntry_2                                          2.6.5 If YES, state locat  dropdown (autocomplete)    {'4': 'Afghanistan', '5':
#   77    78  supper_trcity_2                                           2.6.6 If YES, state locat  textField Annotation: @HI  {}
#   78    79  erendat_2                                                 2.6.7 If YES, return date  text (date_dmy)Field Anno  {}
#   79    80  animal_eryn                                               2.7 Contact with animals,  radio                      {'1': 'Yes', '2': 'No', '
#   80    81  animal_erterm                                             If YES, specify the anima  textField Annotation: @HI  {}
#   81    82  animal_erdat                                              If YES, specify the anima  text (date_dmy), Required  {}
#   82    83  animal_eryn_2                                             2.8 Contact with another   radio                      {'1': 'Yes', '2': 'No', '
#   83    84  animal_erterm_2                                           If YES, specify the anima  textField Annotation: @HI  {}
#   84    85  animal_erdat_2                                            If YES, specify the anima  text (date_dmy)Field Anno  {}
#   85    86  hoyn                                                      Section Header: RE-ADMISS  radio, Required            {'1': 'YES - admitted pre
#   86    87  previous_subjidyn                                         Has this patient's data b  radio, Required            {'1': 'YES', '0': 'NO', '
#   87    88  previous_subjid                                           If YES, Participant Ident  text, RequiredCustom alig  {}
#   88    89  readm_cov19_hoyn                                          Is the patient being re-a  radio, Required            {'1': 'YES', '0': 'NO', '
#   89    90  previous_subjidyn_2                                       If YES, previous particip  radio, Required            {'1': 'YES', '0': 'NO'}
#   90    91  previous_subjid_2                                         Previous participant ID:   text, RequiredCustom alig  {}
#   91    92  number_readm                                              Number of re-admissions (  text, RequiredCustom alig  {}
#   92    93  new_horeas                                                Please provide reason for  text, RequiredCustom alig  {}
#   93    94  onset_and_admission_complete                              Section Header: Form Stat  dropdown                   {'0': 'Incomplete', '1':
#   94    95  sign_symp_banner                                          Please provide details of  descriptive                {}
#   95    96  temp_vsyn                                                 Section Header: SIGNS AND  radio, Required            {'1': 'YES', '0': 'NO', '
#   96    97  temp_vsorres                                              Temperature                text (number), Required    {}
#   97    98  temp_vsorresu                                             Temperature Units          radio, Required            {'1': 'Â°C', '2': 'Â°F'}
#   98    99  hr_vsyn                                                   Heart rate on admission a  radio, Required            {'1': 'YES', '0': 'NO', '
#   99   100  hr_vsorres                                                Heart Ratebeats per minut  text (number), Required    {}
#  100   101  rr_vsyn                                                   Respiratory rate on admis  radio, Required            {'1': 'YES', '0': 'NO', '
#  101   102  rr_vsorres                                                Respiratory Ratebreaths p  text (number), RequiredCu  {}
#  102   103  sysbp_vsyn                                                Systolic blood pressure o  radio, Required            {'1': 'YES', '0': 'NO', '
#  103   104  sysbp_vsorres                                             Systolic blood pressuremm  text (number), RequiredCu  {}
#  104   105  diabp_vsyn                                                Diastolic blood pressure   radio, Required            {'1': 'YES', '0': 'NO', '
#  105   106  admission_diabp_vsorres                                   Diastolic blood pressurem  text (number), RequiredCu  {}
#  106   107  oxy_vsyn                                                  Oxygen saturation on admi  radio, Required            {'1': 'YES', '0': 'NO', '
#  107   108  oxy_vsorres                                               Oxygen saturation%         text (number, Min:         {}
#  108   109  oxy_vsorresu                                              Oxygen saturation on:      radio, Required            {'1': 'Room air', '2': 'O
#  109   110  dehydration_vsorres                                       Severe dehydration:        radio                      {'1': 'Yes', '2': 'No', '
#  110   111  stercap_vsyn                                              Sternal capillary refill   radio, Required            {'1': 'YES', '0': 'NO', '
#  111   112  stercap_vsorres                                           Sternal capillary refill   radio, Required            {'1': 'YES', '2': 'NO', '
#  112   113  height_vsyn                                               Height on admission avail  radio, Required            {'1': 'YES', '0': 'NO', '
#  113   114  height_vsorres                                            Heightcm                   text (number, Min:         {}
#  114   115  weight_vsyn                                               Weight on admission avail  radio, Required            {'1': 'YES', '0': 'NO', '
#  115   116  weight_vsorres                                            Weight                     text (number, Min:         {}
#  116   117  weight_vsorresu                                           Weight Unit                radio, Required            {'1': 'grams', '2': 'kg'}
#  117   118  fever_ceoccur_v2                                          Section Header: SIGNS AND  radio, Required            {'1': 'YES', '2': 'NO', '
#  118   119  cough_ceoccur_v2_2                                        Cough                      radio, Required            {'1': 'YES - non-producti
#  119   120  cough_ceoccur_v2                                          Cough                      radio, Required            {'1': 'YES', '2': 'NO', '
#  120   121  coughsput_ceoccur_v2                                      4a.2.1 Cough: with sputum  radio, Required            {'1': 'YES', '2': 'NO', '
#  121   122  coughhb_ceoccur_v2                                        4a.2.2 Cough: bloody sput  radio, Required            {'1': 'YES', '2': 'NO', '
#  122   123  sorethroat_ceoccur_v2                                     Sore throat                radio, Required            {'1': 'YES', '2': 'NO', '
#  123   124  runnynose_ceoccur_v2                                      Runny nose (Rhinorrhoea)   radio, Required            {'1': 'YES', '2': 'NO', '
#  124   125  earpain_ceoccur_v2                                        4a.5. Ear pain             radio, Required            {'1': 'YES', '2': 'NO', '
#  125   126  wheeze_ceoccur_v2                                         Wheezing                   radio, Required            {'1': 'YES', '2': 'NO', '
#  126   127  shortbreath_ceoccur_v2                                    Shortness of breath (Dysp  radio, Required            {'1': 'YES', '2': 'NO', '
#  127   128  lowerchest_ceoccur_v2                                     Lower chest wall indrawin  radio, Required            {'1': 'YES', '2': 'NO', '
#  128   129  chestpain_ceoccur_v2                                      Chest pain                 radio, Required            {'1': 'YES', '2': 'NO', '
#  129   130  conjunct_ceoccur_v2                                       Conjunctivitis             radio, Required            {'1': 'YES', '2': 'NO', '
#  130   131  lymp_ceoccur_v2                                           Lymphadenopathy            radio, Required            {'1': 'YES', '2': 'NO', '
#  131   132  headache_ceoccur_v2                                       Headache                   radio, Required            {'1': 'YES', '2': 'NO', '
#  132   133  anosmia_ceoccur_v2                                        Loss of smell (Anosmia)    radio, Required            {'1': 'YES', '2': 'NO', '
#  133   134  ageusia_ceoccur_v2                                        Loss of taste (Ageusia)    radio, Required            {'1': 'YES', '2': 'NO', '
#  134   135  seizures_cecoccur_v2                                      Seizures                   radio, Required            {'1': 'YES', '2': 'NO', '
#  135   136  fatigue_ceoccur_v2                                        Fatigue / Malaise          radio, Required            {'1': 'YES', '2': 'NO', '
#  136   137  anorexia_ceoccur_v2                                       Anorexia                   radio, Required            {'1': 'YES', '2': 'NO', '
#  137   138  confusion_ceoccur_v2                                      Altered consciousness / c  radio, Required            {'1': 'YES', '2': 'NO', '
#  138   139  myalgia_ceoccur_v2                                        Muscle aches (Myalgia)     radio, Required            {'1': 'YES', '2': 'NO', '
#  139   140  jointpain_ceoccur_v2                                      Joint pain (Arthralgia)    radio, Required            {'1': 'YES', '2': 'NO', '
#  140   141  inablewalk_ceoccur_v2                                     Inability to walk          radio, Required            {'1': 'YES', '2': 'NO', '
#  141   142  abdopain_ceoccur_v2                                       Abdominal pain             radio, Required            {'1': 'YES', '2': 'NO', '
#  142   143  diarrhoea_ceoccur_v2                                      Diarrhoea                  radio, Required            {'1': 'YES', '2': 'NO', '
#  143   144  vomit_ceoccur_v2                                          Vomiting / Nausea          radio, Required            {'1': 'YES', '2': 'NO', '
#  144   145  rash_ceoccur_v2                                           Skin rash                  radio, Required            {'1': 'YES', '2': 'NO', '
#  145   146  skinulcers_ceoccur_v2                                     4a.20. Skin ulcers         radio, Required            {'1': 'YES', '2': 'NO', '
#  146   147  bleed_ceoccur_v2                                          Bleeding (Haemorrhage)     radio, Required            {'1': 'YES', '2': 'NO', '
#  147   148  bleed_cetermy_v2                                          Bleeding (Haemorrhage) -   text, RequiredCustom alig  {}
#  148   149  other_ceoccur_v2                                          Other sign or symptom      radio, Required            {'1': 'YES', '2': 'NO', '
#  149   150  bleed_ceterm_v2                                           4a.23. If Bleeding (other  radio, Required            {'1': 'YES', '2': 'NO', '
#  150   151  other_cetermy_v2                                          Other sign or symptom - i  text, Required             {}
#  151   152  admission_signs_and_symptoms_complete                     Section Header: Form Stat  dropdown                   {'0': 'Incomplete', '1':
#  152   153  vacc_cov19_cmyn                                           Section Header: VACCINATI  radio, Required            {'1': 'YES', '0': 'NO', '
#  153   154  vacc_cov19_cmdat                                          Estimated date of most re  text (date_dmy), Required  {}
#  154   155  vacc_cov19_cmdoses                                        If YES, number of doses r  text (integer, Min:        {}
#  155   156  vacc_cov19_recent_cmtrt                                   If YES, specify type of t  dropdown, Required         {'1': 'Pfizer/BioNTech',
#  156   157  vacc_cov19_recent_cmoth                                   If other, please specify:  text, RequiredCustom alig  {}
#  157   158  vacc_cov19_previous_cmtrt                                 If more than one dose has  checkbox, Required         {}
#  158   159  vacc_cov19_previous_cmoth                                 If other, please specify:  text, RequiredCustom alig  {}
#  159   160  vacc_flu_cmyn                                             Influenza vaccination wit  radio, Required            {'1': 'YES', '0': 'NO', '
#  160   161  vaccinations_complete                                     Section Header: Form Stat  dropdown                   {'0': 'Incomplete', '1':
#  161   162  pre_ace_cmoccur                                           Section Header: PRE-ADMIS  radio                      {'1': 'YES', '2': 'NO', '
#  162   163  pre_arb_cmoccur                                           Angiotensin II receptor b  radio                      {'1': 'YES', '2': 'NO', '
#  163   164  pre_nsaid_cmoccur                                         Non-steroidal anti-inflam  radio, Required            {'1': 'YES', '2': 'NO', '
#  164   165  pre_oralsteroid_cmoccur                                   Oral steroids              radio                      {'1': 'YES', '2': 'NO', '
#  165   166  pre_oralsteroid_cmtype                                    Oral steroids - if YES, a  textField Annotation: @HI  {}
#  166   167  pre_steroid_cmoccur                                       Steroids                   radio, Required            {'1': 'YES', '0': 'NO', '
#  167   168  pre_steroid_cmroute                                       If Steroids is YES, route  radio, Required            {'1': 'Oral', '2': 'Inhal
#  168   169  pre_nonoralsteroid_cmoccur                                Other immunosuppressant a  radio, Required            {'1': 'YES', '2': 'NO', '
#  169   170  pre_nonoralsteroid_cmtype                                 Other immunosuppressant a  textField Annotation: @HI  {}
#  170   171  pre_antibiotic_cmoccur                                    Antibiotics                radio, Required            {'1': 'YES', '2': 'NO', '
#  171   172  pre_antibiotic_cmtype                                     Antibiotics - if YES, age  text, Required             {}
#  172   173  pre_antiviral_cmoccur                                     Antivirals                 radio, Required            {'1': 'YES', '2': 'NO', '
#  173   174  pre_antiviral_cmtype                                      Antivirals - if YES, agen  text, Required             {}
#  174   175  pre_othmed_cmoccur                                        Other targeted COVID-19 M  radio, Required            {'1': 'YES', '2': 'NO', '
#  175   176  pre_othmed_cmtype                                         Other targeted COVID-19 M  text, Required             {}
#  176   177  pre_admission_medication_complete                         Section Header: Form Stat  dropdown                   {'0': 'Incomplete', '1':
#  177   178  comorb_banner                                             Please record if any of t  descriptive                {}
#  178   179  chroniccard_mhyn                                          Section Header: CO-MORBID  radio, Required            {'1': 'YES', '2': 'NO', '
#  179   180  hypertension_mhyn                                         Hypertension               radio, Required            {'1': 'YES', '2': 'NO', '
#  180   181  chronicpul_mhyn                                           Chronic pulmonary disease  radio, Required            {'1': 'YES', '2': 'NO', '
#  181   182  asthma_mhyn                                               Asthma (physician diagnos  radio, Required            {'1': 'YES', '2': 'NO', '
#  182   183  renal_mhyn                                                Chronic kidney disease     radio, Required            {'1': 'YES', '2': 'NO', '
#  183   184  obesity_mhyn                                              Obesity (as defined by cl  radio, Required            {'1': 'YES', '2': 'NO', '
#  184   185  modliver_mhyn                                             Moderate or severe liver   radio, Required            {'1': 'YES', '2': 'NO', '
#  185   186  mildliv_mhyn                                              Mild liver disease         radio, Required            {'1': 'YES', '2': 'NO', '
#  186   187  asplenia_mhyn                                             Asplenia                   radio, Required            {'1': 'YES', '2': 'NO', '
#  187   188  chronicneu_mhyn                                           Chronic neurological diso  radio, Required            {'1': 'YES', '2': 'NO', '
#  188   189  malignantneo_mhyn                                         Malignant neoplasm         radio, Required            {'1': 'YES', '2': 'NO', '
#  189   190  chronhaemo_mhyn                                           Chronic hematologic disea  radio, Required            {'1': 'YES', '2': 'NO', '
#  190   191  aidshiv_mhyn_2                                            AIDS / HIV                 radio, Required            {'1': 'YES - on ART', '4'
#  191   192  aidshiv_cd4                                               AIDS / HIV - if YES, most  radio, Required            {'1': '< 200 cells/uL', '
#  192   193  diabetes_mhyn_2                                           Diabetes Mellitus          radio, Required            {'1': 'YES - Type 1', '4'
#  193   194  hba1c_mborres                                             Diabetes Mellitus - if YE  text, Required             {}
#  194   195  hba1c_mborresu                                            Hba1c - units              dropdown, Required         {'1': 'mmol/mol', '2': 'm
#  195   196  aidshiv_mhyn                                              4b.10. AIDS/HIV            radio                      {'1': 'YES', '2': 'NO', '
#  196   197  diabetiscomp_mhyn                                         4b.12. Diabetes with comp  radio                      {'1': 'YES', '2': 'NO', '
#  197   198  diabetes_mhyn                                             4b.13. Diabetes without c  radio                      {'1': 'YES', '2': 'NO', '
#  198   199  rheumatology_mhyr                                         Rheumatologic disorder     radio, Required            {'1': 'YES', '2': 'NO', '
#  199   200  dementia_mhyn                                             Dementia                   radio, Required            {'1': 'YES', '2': 'NO', '
#  200   201  tb_mhyn                                                   Tuberculosis               radio, Required            {'1': 'YES', '2': 'NO', '
#  201   202  malnutrition_mhyn                                         Malnutrition               radio, Required            {'1': 'YES', '2': 'NO', '
#  202   203  smoking_mhyn                                              Smoking                    radio, Required            {'1': 'Yes', '2': 'Never
#  203   204  other_mhyn                                                Other relevant risk facto  radio, Required            {'1': 'YES', '2': 'NO', '
#  204   205  otherrisktext                                             Other relevant risk facto  text                       {}
#  205   206  comorbidities_complete                                    Section Header: Form Stat  dropdown                   {'0': 'Incomplete', '1':
#  206   207  daily_form_banner                                         MODULE 2: CASE REPORT FOR  descriptive                {}
#  207   208  daily_dsstdat                                             Section Header: SIGNS AND  text (date_dmy), Required  {}
#  208   209  daily_temp_vsyn                                           Temperature available?     radio, Required            {'1': 'YES', '0': 'NO', '
#  209   210  daily_temp_vsorres                                        Highest temperature        text (number), Required    {}
#  210   211  daily_temp_vsorresu                                       Temperature Unit           radio, Required            {'1': 'Â°C', '2': 'Â°F'}
#  211   212  daily_hr_vsyn                                             Heart rate available?      radio, Required            {'1': 'YES', '0': 'NO', '
#  212   213  daily_hr_vsorres                                          Heart Ratebeats per minut  text (number), Required    {}
#  213   214  daily_rr_vsyn                                             Respiratory rate availabl  radio, Required            {'1': 'YES', '0': 'NO', '
#  214   215  daily_rr_vsorres                                          Respiratory Ratebreaths p  text (number), Required    {}
#  215   216  systolic_vsyn                                             Systolic Blood Pressure a  radio, Required            {'1': 'YES', '0': 'NO', '
#  216   217  systolic_vsorres                                          Systolic PressuremmHg      text, Required             {}
#  217   218  diastolic_vsyn                                            Diastolic Blood Pressure   radio, Required            {'1': 'YES', '0': 'NO', '
#  218   219  diastolic_vsorres                                         Diastolic PressuremmHg     text, Required             {}
#  219   220  daily_oxy_vsyn                                            Oxygen saturation availab  radio, Required            {'1': 'YES', '0': 'NO', '
#  220   221  daily_oxy_vsorres                                         Oxygen saturation SaO2%    text (number, Min:         {}
#  221   222  daily_fi02_lbyn                                           Any supplemental oxygen:   radio, Required            {'1': 'YES', '2': 'NO', '
#  222   223  daily_fio2_lborres                                        FiO2(0.21-1.0)             text (number, Min:         {}
#  223   224  daily_fio2b_lborres                                       FiO2 %%                    text (number, Min:         {}
#  224   225  daily_fio2c_lborres                                       FiO2 L/min (Highest L/min  text (number, Min:         {}
#  225   226  daily_pao2_lbyn                                           PaO2 available?            radio, Required            {'1': 'YES', '0': 'NO', '
#  226   227  daily_pao2_lborres                                        PaO2 (at time nearest to   text (number, Min:         {}
#  227   228  daily_pao2_lborresu                                       PaO2 unit:                 dropdown, Required         {'1': 'kPa', '2': 'mmHg'}
#  228   229  daily_pao2_lbspec                                         PaO2 sample type           dropdown, Required         {'1': 'Arterial', '3': 'C
#  229   230  daily_pco2_lbyn                                           PCO2 available? (from sam  radio, Required            {'1': 'YES', '2': 'NO', '
#  230   231  daily_pco2_lborres                                        PCO2                       text (number, Min:         {}
#  231   232  daily_pco2_lborresu                                       PCO2 Unit                  dropdown, Required         {'1': 'kPa', '2': 'mmHg'}
#  232   233  daily_ph_lbyn                                             pH available?              radio, Required            {'1': 'YES', '0': 'NO', '
#  233   234  daily_ph_lborres                                          pH                         text (number, Min:         {}
#  234   235  daily_hco3_lbyn                                           HCO3-  available?          radio, Required            {'1': 'YES', '0': 'NO', '
#  235   236  daily_hco3_lborres                                        HCO3-                      text (number, Min:         {}
#  236   237  daily_hco3_lborresu                                       HCO3- Unit                 dropdown, Required         {'1': 'mmol/L', '2': 'mEq
#  237   238  daily_baseex_lbyn                                         Base excess available?     radio, Required            {'1': 'YES', '0': 'NO', '
#  238   239  daily_baseex_lborres                                      Base excessmmol/L          text, Required             {}
#  239   240  daily_sa02_lbyn                                           1.3  SaO2 available?       radio                      {'1': 'YES', '2': 'NO', '
#  240   241  daily_sao2_lborres                                        SaO2  %                    text (number, Min:         {}
#  241   242  daily_stercap_vsorres                                     Sternal capillary refill   radio, Required            {'1': 'YES', '0': 'NO', '
#  242   243  avpu_vsorres                                              AVPU                       radio, Required            {'1': 'Alert', '2': 'Verb
#  243   244  daily_gcs_lbyn                                            Glasgow Coma Score availa  radio, Required            {'1': 'Yes', '0': 'No'}
#  244   245  daily_gcs_vsorres                                         Glasgow Coma Score (GCS /  text (number, Min:         {}
#  245   246  rass_sas_vsyn                                             Richmond Agitation-Sedati  dropdown                   {'1': 'YES - RASS availab
#  246   247  rass_vsyn                                                 Richmond Agitation-Sedati  yesno, Required            {'1': 'Yes', '0': 'No'}
#  247   248  rass_vsorres                                              Richmond Agitation-Sedati  text (number), Required    {}
#  248   249  sas_vsyn                                                  Riker Sedation-Agitation   yesno                      {'1': 'Yes', '0': 'No'}
#  249   250  sas_vsorres                                               Riker Sedation-Agitation   text (number)Field Annota  {}
#  250   251  daily_meanart_lbyn                                        Mean Arterial Pressure av  radio, Required            {'1': 'YES', '0': 'NO', '
#  251   252  daily_meanart_vsorres                                     Mean Arterial Pressure:mm  text (number, Min:         {}
#  252   253  daily_urine_lbyn                                          Urine flow rate available  radio, Required            {'1': 'Yes', '2': 'Estima
#  253   254  daily_urine_lborres                                       Urine flow rate:mL/24 hou  text (number, Min:         {}
#  254   255  daily_hoterm                                              Section Header: Is the pa  radio, Required            {'1': 'YES', '2': 'NO', '
#  255   256  daily_nasaloxy_cmtrt                                      High-flow nasal canula ox  radio, Required            {'1': 'YES', '2': 'NO', '
#  256   257  daily_noninvasive_prtrt                                   Non-invasive ventilation   radio, Required            {'1': 'YES', '2': 'NO', '
#  257   258  daily_noninvasive_prtype                                  Non-invasive ventilation   radio, Required            {'1': 'BIPAP', '2': 'CPAP
#  258   259  daily_invasive_prtrt                                      Invasive ventilation?      radio, Required            {'1': 'YES', '2': 'NO', '
#  259   260  daily_prone_cmtrt                                         Prone Positioning?         radio, Required            {'1': 'YES', '2': 'NO', '
#  260   261  daily_prone_cmtype                                        Prone Positioning, if YES  radio, Required            {'1': 'during invasive ve
#  261   262  daily_nitritc_cmtrt                                       Inhaled Nitric Oxide ?     radio, Required            {'1': 'YES', '2': 'NO', '
#  262   263  daily_trach_prperf                                        Tracheostomy inserted?     radio, Required            {'1': 'YES', '2': 'NO', '
#  263   264  daily_ecmo_prtrt                                          Extra corporeal life supp  radio, Required            {'1': 'YES', '2': 'NO', '
#  264   265  daily_ecmo_prtype                                         Extra corporeal life supp  radio, Required            {'1': 'VV', '2': 'AV', '3
#  265   266  daily_rrt_cmtrt                                           Renal replacement therapy  radio, Required            {'1': 'YES', '2': 'NO', '
#  266   267  daily_inotrope_cmyn                                       Any vasopressor / inotrop  radio, Required            {'1': 'YES', '2': 'NO', '
#  267   268  daily_dopless5_cmtrt                                      Dopamine < 5 Âµg/kg/min O  radio, Required            {'1': 'YES', '2': 'NO', '
#  268   269  daily_dop5to15_cmtrt                                      Dopamine 5-15 Âµg/kg/min   radio, Required            {'1': 'YES', '2': 'NO', '
#  269   270  daily_dopgr15_cmtrt                                       Dopamine > 15 Âµg/kg/min   radio, Required            {'1': 'YES', '2': 'NO', '
#  270   271  daily_neuro_cmtrt                                         Neuromuscular blocking ag  radio, Required            {'1': 'YES', '2': 'NO', '
#  271   272  daily_prperf                                              Other intervention(s) or   radio, Required            {'1': 'YES', '2': 'NO', '
#  272   273  daily_other_prtrt                                         Other intervention(s) or   text, Required             {}
#  273   274  daily_lbperf                                              Section Header: LABORATOR  yesno, Required            {'1': 'Yes', '0': 'No'}
#  274   275  daily_lbdat                                               Date of assessment         text (date_dmy), Required  {}
#  275   276  daily_lab_banner                                          LABORATORY RESULTS (*reco  descriptive                {}
#  276   277  daily_hb_lbyn                                             Haemoglobin available?     radio, Required            {'1': 'YES', '0': 'NO', '
#  277   278  daily_hb_lborres                                          Haemoglobin                text (number, Min:         {}
#  278   279  daily_hb_lborresu                                         Haemoglobin Unit           dropdown, Required         {'2': 'g/dL', '1': 'g/L',
#  279   280  daily_wbc_lbyn                                            WBC count available?       radio, Required            {'1': 'YES', '0': 'NO', '
#  280   281  daily_wbc_lborres                                         WBC count                  text (number, Min:         {}
#  281   282  daily_wbc_lborresu                                        WBC Unit                   dropdown, Required         {'1': 'x 10^9 / L', '2':
#  282   283  daily_lymp_lbyn                                           Lymphocyte count availabl  radio, Required            {'1': 'YES', '0': 'NO', '
#  283   284  daily_lymp_lborres                                        Lymphocyte count           text (number, Min:         {}
#  284   285  daily_lymp_lborresu                                       Lymphocyte Unit            dropdown, Required         {'1': '10^9 cells/L', '2'
#  285   286  daily_neutro_lbyn                                         Neutrophil count availabl  radio, Required            {'1': 'YES', '0': 'NO', '
#  286   287  daily_neutro_lborres                                      Neutrophil count           text (number, Min:         {}
#  287   288  daily_neutro_lborresu                                     Neutrophil Unit            dropdown, Required         {'1': '10^9 cells/L', '2'
#  288   289  daily_haematocrit_lbyn                                    Haematocrit available?     radio, Required            {'1': 'YES', '0': 'NO', '
#  289   290  daily_haematocrit_lborres                                 Haematocrit                text (number, Min:         {}
#  290   291  daily_haematocrit_lborresu                                Haematocrit Unit           dropdown, Required         {'1': 'Proportion', '2':
#  291   292  daily_plt_lbyn                                            Platelets available?       radio, Required            {'1': 'YES', '0': 'NO', '
#  292   293  daily_plt_lborres                                         Platelet Count             text (number, Min:         {}
#  293   294  daily_plt_lborresu                                        Platelets Unit             dropdown, Required         {'1': 'x 10^9 / L', '2':
#  294   295  daily_aptt_lbyn                                           2.8 APTT/APTR available    yesno                      {'1': 'Yes', '0': 'No'}
#  295   296  daily_aptt_lborres                                        APTT/APTR                  text (number, Min:         {}
#  296   297  daily_aptt_lbyn_2                                         APTT available?            radio, Required            {'1': 'YES', '0': 'NO', '
#  297   298  daily_aptt_lborres_2                                      APTTseconds                text (number, Min:         {}
#  298   299  daily_aptr_lbyn                                           APTR available?            radio, Required            {'1': 'YES', '0': 'NO', '
#  299   300  daily_aptr_lborres                                        APTRratio                  text (number, Min:         {}
#  300   301  daily_pt_inr_lbyn                                         PT or INR available?       dropdown                   {'1': 'PT done', '2': 'IN
#  301   302  daily_pt_lbyn                                             PT available?              radio, Required            {'1': 'YES', '0': 'NO', '
#  302   303  daily_pt_lborres                                          PT seconds                 text (number, Min:         {}
#  303   304  daily_inr_lbyn                                            INR available?             radio, Required            {'1': 'YES', '0': 'NO', '
#  304   305  daily_inr_lborres                                         INRratio                   text (number, Min:         {}
#  305   306  daily_alt_lbyn                                            ALT/SGPT available?        radio, Required            {'1': 'YES', '0': 'NO', '
#  306   307  daily_alt_lborres                                         ALT/SGPT                   text (number, Min:         {}
#  307   308  daily_alt_lborresu                                        ALT/SGPT Unit              dropdown, Required         {'1': 'U/L', '2': 'nkat/L
#  308   309  daily_bil_lbyn                                            Total Bilirubin available  radio, Required            {'1': 'YES', '0': 'NO', '
#  309   310  daily_bil_lborres                                         Total Bilirubin            text (number, Min:         {}
#  310   311  daily_bil_lborresu                                        Total Bilirubin Unit       dropdown, Required         {'1': 'Âµmol/L', '2': 'mg
#  311   312  daily_ast_lbyn                                            AST/SGOT available?        radio, Required            {'1': 'YES', '0': 'NO', '
#  312   313  daily_ast_lborres                                         AST/SGOT                   text (number, Min:         {}
#  313   314  daily_ast_lborresu                                        AST/SGOT Unit              dropdown, Required         {'1': 'U/L', '2': 'nkat/L
#  314   315  daily_glucose_lbyn                                        Glucose available?         radio, Required            {'1': 'YES', '0': 'NO', '
#  315   316  daily_glucose_lborres                                     Glucose                    text (number, Min:         {}
#  316   317  daily_glucose_lborresu                                    Glucose Unit               dropdown, Required         {'1': 'mmol/L', '2': 'mg/
#  317   318  daily_bun_lbyn                                            Urea (BUN) available?      radio, Required            {'1': 'YES', '0': 'NO', '
#  318   319  daily_bun_lborres                                         Urea (BUN)                 text (number, Min:         {}
#  319   320  daily_bun_lborresu                                        Urea (BUN) Unit            dropdown, Required         {'1': 'mmol/L', '2': 'mg/
#  320   321  daily_lactate_lbyn                                        Lactate available?         radio, Required            {'1': 'YES', '0': 'NO', '
#  321   322  daily_lactate_lborres                                     Lactate                    text (number, Min:         {}
#  322   323  daily_lactate_lborresu                                    Lactate Unit               dropdown, Required         {'1': 'mmol/L', '2': 'mg/
#  323   324  daily_creat_lbyn                                          Serum Creatinine availabl  radio, Required            {'1': 'YES', '0': 'NO', '
#  324   325  daily_creat_lborres                                       Serum Creatinine           text (number, Min:         {}
#  325   326  daily_creat_lborresu                                      Serum Creatinine Unit      dropdown, Required         {'1': 'Âµmol', '3': 'Âµmo
#  326   327  daily_sodium_lbyn                                         Sodium  available?         radio, Required            {'1': 'YES', '0': 'NO', '
#  327   328  daily_sodium_lborres                                      Sodium                     text (number, Min:         {}
#  328   329  daily_sodium_lborresu                                     Sodium Unit                dropdown, Required         {'1': 'mmol/L', '2': 'mEq
#  329   330  daily_potassium_lbyn                                      Potassium available?       radio, Required            {'1': 'YES', '0': 'NO', '
#  330   331  daily_potassium_lborres                                   Potassium                  text (number, Min:         {}
#  331   332  daily_potassium_lborresu                                  Potassium Unit             dropdown, Required         {'1': 'mmol/L', '2': 'mEq
#  332   333  daily_procal_lbyn                                         Procalcitonin available?   radio, Required            {'1': 'YES', '0': 'NO', '
#  333   334  daily_procal_lborres                                      Procalcitonin              text (number, Min:         {}
# ...
#  961   962  flw2_eq5d5l_copy2_uk_eng_4                                Â© EuroQol Research Found  descriptive                {}
#  962   963  flw2_eq5d_sc_5l_uk_eng_2                                  SELF-CARE                  radio                      {'1': 'I have no problems
#  963   964  flw2_eq5d5l_copy2_uk_eng_5                                Â© EuroQol Research Found  descriptive                {}
#  964   965  flw2_eq5d_ua_5l_uk_eng_2                                  USUAL ACTIVITIES  (e.g. w  radio                      {'1': 'I have no problems
#  965   966  flw2_eq5d5l_copy3_uk_eng                                  Â© EuroQol Research Found  descriptive                {}
#  966   967  flw2_eq5d_pd_5l_uk_eng                                    PAIN / DISCOMFORT          radio                      {'1': 'I have no pain or
#  967   968  flw2_eq5d5l_copy3_uk_eng_2                                Â© EuroQol Research Found  descriptive                {}
#  968   969  flw2_eq5d_ad_5l_uk_eng                                    ANXIETY / DEPRESSION       radio                      {'1': 'I am not anxious o
#  969   970  flw2_eq5d5l_copy5_uk_eng                                  Â© EuroQol Research Found  descriptive                {}
#  970   971  flw2_eq5d5l_vas2_uk_eng                                   We would like to know how  slider (number)Slider lab  {}
#  971   972  flw2_eq5d5l_copy6_uk_eng                                  Â© EuroQol Research Found  descriptive                {}
#  972   973  flw2_breathless_now                                       Section Header: 6. Breath  dropdown                   {'1': 'Not troubled by br
#  973   974  flw2_fatigue                                              If known, please rate the  text (number, Min:         {}
#  974   975  flw2_seeing_today                                         Section Header: 7. The ne  radio                      {'1': 'No - no difficulty
#  975   976  flw2_hearing_today                                        Do you have difficulty he  radio                      {'1': 'No - no difficulty
#  976   977  flw2_walking_today                                        Do you have difficulty wa  radio                      {'1': 'No - no difficulty
#  977   978  flw2_remember_today                                       Do you have difficulty re  radio                      {'1': 'No - no difficulty
#  978   979  flw2_washing_today                                        Do you have difficulty (w  radio                      {'1': 'No - no difficulty
#  979   980  flw2_comm_today                                           Using your usual (customa  radio                      {'1': 'No - no difficulty
#  980   981  flw2_smoking                                              Section Header: 8. Have y  radio                      {'1': 'I do this more oft
#  981   982  flw2_alcohol                                              Drinking alcohol           radio                      {'1': 'I do this more oft
#  982   983  flw2_healthy_eating                                       Eating healthy food        radio                      {'1': 'I do this more oft
#  983   984  flw2_phys_activ                                           Physical activity (includ  radio                      {'1': 'I do this more oft
#  984   985  flw2_employ_pre_c19                                       Section Header: 9. A few   dropdown                   {'1': 'Working Full-time'
#  985   986  flw2_employ_chg                                           What is your main occupat  dropdown                   {'1': 'Same as before', '
#  986   987  flw2_employ_today                                         If different, please desc  checkbox                   {}
#  987   988  flw2_employ_chg_reason                                    If different, why did you  dropdown                   {'1': 'Poor health', '2':
#  988   989  flw2_employ_chg_other                                     (If employment status has  textCustom alignment: LH   {}
#  989   990  flw2_sick_leave                                           Have you been on sick lea  radio                      {'1': 'Yes', '0': 'No', '
#  990   991  flw2_sick_leave_time                                      If 'yes', for how long ha  text (number)Custom align  {}
#  991   992  flw2_sick_leave_days                                      Days or weeks?             radio                      {'10': 'Days', '11': 'Wee
#  992   993  flw2_sex_at_birth                                         Section Header: 10. A few  dropdown, Required         {'1': 'Male', '2': 'Femal
#  993   994  flw2_ethnicity                                            Ethnicity:                 dropdown, Required         {'1': 'White', '2': 'Arab
#  994   995  flw2_ethnicity_oth                                        Other ethnicity            text                       {}
#  995   996  flw2_height                                               What is your estimated he  text (number, Min:         {}
#  996   997  flw2_height_unit                                          Height: Indicate unit mea  radio                      {'1': 'metres', '2': 'cen
#  997   998  flw2_weight                                               What is your current esti  text (number, Min:         {}
#  998   999  flw2_weight_unit                                          Weight: Indicate unit mea  radio                      {'1': 'kg', '2': 'lbs', '
#  999  1000  flw2_how_many_household                                   How many other members re  text (number, Min:         {}
# 1000  1001  flw2_highest_edu                                          What is your highest comp  dropdown                   {'1': 'Primary education
# 1001  1002  flw2_other_ed_specify                                     If other, please specify:  text                       {}
# 1002  1003  flw2_num_edu                                              Number of years in formal  text (number)              {}
# 1003  1004  flw2_c19_effects                                          Please let us know if you  notes                      {}
# 1004  1005  flw2_thank_you                                            END OF SURVEY              descriptive                {}
#
#                                                                       			Thank Y
# 1005  1006  follow_up_self_assessment_survey_long_term_complete       Section Header: Form Stat  dropdown                   {'0': 'Incomplete', '1':
# 1006  1007  p_subjid                                                  Section Header: Participa  text                       {}
# 1007  1008  edlvrdtc_rporres                                          Section Header: Status on  text (date_dmy), Required  {}
# 1008  1009  preg_apid                                                 Expected estimated date o  radio, Required            {'1': 'Singleton', '2': '
# 1009  1010  preg_apid_oth                                             Expected estimated date o  text, Required             {}
# 1010  1011  comp_ceyn                                                 1.2 Pregnancy related com  radio, Required            {'1': 'Yes', '2': 'No', '
# 1011  1012  comp_ceoccur                                              Pregnancy related complic  checkbox, Required         {}
# 1012  1013  comp_ceterm_oth                                           Pregnancy related complic  text, RequiredCustom alig  {}
# 1013  1014  cmyn                                                      1.3 Any medication taken   radio, Required            {'1': 'Yes', '2': 'No', '
# 1014  1015  cmtrt                                                     Medication taken during p  notes, RequiredCustom ali  {}
# 1015  1016  brthn_yn                                                  Section Header: Previous   checkbox, Required         {'1': 'brthn_yn___1', 'Ye
# 1016  1017  brthn_rporres_1                                           Previous completed pregna  text (integer, Min:        {}
# 1017  1018  brthn_rporres_2                                           Previous completed pregna  text (integer, Min:        {}
# 1018  1019  prob_mhyn                                                 2.2 Did the woman have an  radio, Required            {'1': 'Yes', '2': 'No', '
# 1019  1020  prob_mhoccur                                              Did the woman have any pr  checkbox, Required         {'1': 'prob_mhoccur___1',
# 1020  1021  prob_mhterm_oth                                           Did the woman have any pr  text, RequiredCustom alig  {}
# 1021  1022  p_hooccur                                                 Section Header: Delivery   radio, Required            {'1': 'Yes', '2': 'No'}
# 1022  1023  dlvr_cestdat                                              Delivery during admission  text (date_dmy), Required  {}
# 1023  1024  ind_proccur                                               3.2 Was labour induced?    radio, Required            {'1': 'Yes', '2': 'No', '
# 1024  1025  ind_prindc                                                Was labour induced - If y  text, RequiredCustom alig  {}
# 1025  1026  cae_proccur                                               3.3 Was delivery via caes  radio, Required            {'1': 'Yes - emergency',
# 1026  1027  cae_agtrt                                                 Was delivery via caesaria  radio, Required            {'1': 'Regional', '2': 'G
# 1027  1028  mis_ceoccur                                               3.4 Did the woman have a   radio, Required            {'1': 'Yes', '2': 'No', '
# 1028  1029  mis_cestdat                                               Did the woman have a misc  text (date_dmy), Required  {}
# 1029  1030  term_ceoccur                                              3.5 Did the woman have a   radio                      {'1': 'Yes', '2': 'No', '
# 1030  1031  term_cestdat                                              Did the woman have a       text (date_dmy), Required  {}
#                                                                       			t
# 1031  1032  termin_prindc                                             Did the woman have a       radio, Required            {'1': 'Yes', '2': 'No', '
#                                                                       			t
# 1032  1033  termin_prindc_oth                                         If yes was the terminatio  text, RequiredCustom alig  {}
# 1033  1034  amniotic_mbspec                                           3.6a Were any of the foll  radio, Required            {'1': 'Amniotic fluid', '
# 1034  1035  amniotic_mbtest                                           Were any of the following  text, RequiredCustom alig  {}
# 1035  1036  placenta_mbspec                                           3.6b Were any of the foll  radio, Required            {'1': 'Placenta', '2': 'N
# 1036  1037  placenta_mbtest                                           Were any of the following  text, RequiredCustom alig  {}
# 1037  1038  cord_mbspec                                               3.6c Were any of the foll  radio, Required            {'1': 'Cord blood', '2':
# 1038  1039  cord_mbtest                                               Were any of the following  text, RequiredCustom alig  {}
# 1039  1040  vswab_mbspec                                              3.6d Were any of the foll  radio, Required            {'1': 'Vaginal swab', '2'
# 1040  1041  vswab_mbtest                                              Were any of the following  text, RequiredCustom alig  {}
# 1041  1042  frswab_mbspec                                             3.6e Were any of the foll  radio, Required            {'1': 'Faecal/rectal swab
# 1042  1043  frswab_mbtest                                             Were any of the following  text, RequiredCustom alig  {}
# 1043  1044  tissue_mbspec                                             3.6f Were any of the foll  radio, Required            {'1': 'Pregnancy tissue',
# 1044  1045  tissue_mbtest                                             Were any of the following  text, RequiredCustom alig  {}
# 1045  1046  apdm_brthdat                                              Section Header: Neonate d  text (date_dmy), Required  {}
# 1046  1047  rsubjid                                                   4.2 Participant ID of the  text, RequiredCustom alig  {}
# 1047  1048  p_aplb_lborres                                            4.3 COVID-19 lab test of   radio, Required            {'1': 'Yes Positive', '2'
# 1048  1049  aplb_lbevintx                                             COVID-19 lab test of foet  radio, Required            {'1': '?12 hours of deliv
# 1049  1050  dlvr_ceterm                                               4.4 Mode of delivery       radio, Required            {'1': 'Spontaneous vagina
# 1050  1051  aprs_apgar_rsorres                                        4.5 Apgar score at 5 minu  text (integer, Min:        {}
# 1051  1052  apsc_egestage_scorres                                     4.6 Gestational age, week  text (integer, Min:        {}
# 1052  1053  apsc_egestage_scorres2                                    Gestational age, days: Da  text (integer), RequiredC  {}
# 1053  1054  apdm_sex                                                  4.7 Sex of infant:         radio, Required            {'1': 'Male', '2': 'Femal
# 1054  1055  apvs_weight_vsorres                                       4.8 Birth weightGrams      text, RequiredCustom alig  {}
# 1055  1056  still_ceoccur                                             4.9 Was the infant stillb  radio, Required            {'1': 'Yes', '2': 'No', '
# 1056  1057  still_cestdat                                             Was the infant stillborn   text (date_dmy), Required  {}
# 1057  1058  neounit_hoterm                                            4.10 Was the infant admit  radio, Required            {'1': 'Yes', '2': 'No', '
# 1058  1059  apho_hodur                                                Was the infant admitted t  text, RequiredCustom alig  {}
# 1059  1060  apho_hoongo                                               Was the infant admitted t  yesno, Required            {'1': 'Yes', '0': 'No'}
# 1060  1061  apae_aeyn                                                 4.11 Did any infant compl  radio, Required            {'1': 'Yes', '2': 'No', '
# 1061  1062  apae_aeterm                                               Did any infant complicati  checkbox, Required         {}
# 1062  1063  apae_aeterm_oth                                           Did any infant complicati  textCustom alignment: RH   {}
# 1063  1064  apce_ceyn                                                 4.12 Did the infant have   radio, Required            {'1': 'Yes', '2': 'No', '
# 1064  1065  apce_ceterm                                               Did the infant have a con  checkbox, Required         {}
# 1065  1066  apce_ceterm_oth                                           Did the infant have a con  text, RequiredCustom alig  {}
# 1066  1067  apds_dsterm                                               4.13 Neonatal outcome      radio, Required            {'1': 'Discharged healthy
# 1067  1068  apds_dsterm_oth                                           Neonatal outcome  - Disch  text, RequiredCustom alig  {}
# 1068  1069  apdm_dthdtc                                               Neonatal outcome - death   text (date_dmy), Required  {}
# 1069  1070  apdd_prcdth_ddorres                                       4.14 If neonate died, wha  radio, Required            {'1': 'Preterm', '2': 'Lo
# 1070  1071  apdd_prcdth_ddorres_spec                                  If neonate died, what was  text, RequiredCustom alig  {}
# 1071  1072  apdd_prcdth_ddorres_oth                                   If neonate died, what was  text, RequiredCustom alig  {}
# 1072  1073  pregnancy_module_complete                                 Section Header: Form Stat  dropdown                   {'0': 'Incomplete', '1':
# ====  ====  ========================================================  ==========================  =========================  =========================
